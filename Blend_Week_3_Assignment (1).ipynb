# %%
import os
os.path.exists("/content/Cloud Warehouse Compersion Chart.csv")
# Out:
# True

# %%
from pyspark.sql.functions import col, regexp_extract, when

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Cloud_Warehouse_ETL") \
    .getOrCreate()

df = spark.read.csv(
    "/content/Cloud Warehouse Compersion Chart.csv",
    header=True,
    inferSchema=True
)

# %%
df.printSchema()
df.show(10, truncate=False)
# Out:
# root
#  |-- index: integer (nullable = true)
#  |-- Shiprocket: string (nullable = true)
#  |-- Unnamed: 1: string (nullable = true)
#  |-- INCREFF: string (nullable = true)
#
# +-----+--------------------------------------------------+----------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |index|Shiprocket                                        |Unnamed: 1      |INCREFF                                                                                                                                                                                           |
# +-----+--------------------------------------------------+----------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |0    |Heads                                             |Price (Per Unit)|Price (Per Unit)                                                                                                                                                                                  |
# |1    |Inbound (Fresh Stock and RTO)                     |₹4.00           |4                                                                                                                                                                                                 |
# |2    |Outbound                                          |₹7.00           |11                                                                                                                                                                                                |
# |3    |Storage Fee/Cft                                   |₹25.00          |Rs 0.15/- Per Day                                                                                                                                                                                 |
# |4    |Customer Return with Detailed QC                  |₹6.00           |15.5                                                                                                                                                                                              |
# |5    |(A) SCOPE OF WORK and STANDARD OPERATING PROCEDURE|NULL            |NULL                                                                                                                                                                                              |
# |6    |Inward                                            |Unloading       |• Boxes counted and weighed. Data captured in the Maven.                                                                                                                                          |
# |7    |NULL                                              |Validation      |• GRN will be initiated against a valid PO document and Invoice will be captured                                                                                                                  |
# |8    |NULL                                              |QC              |• No QC to be done (Outer Visual Inspection and Color matching)                                                                                                                                   |
# |9    |NULL                                              |GRN             |•  Scanning (Goods will have scannable EAN code or unique barcodes) and counting of all inventory, verification of all data by supervisor and completion of GRN. Detailed report is made available|
# +-----+--------------------------------------------------+----------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows

# %%
from pyspark.sql.functions import col

df_clean = df.select(
    col("Shiprocket").alias("service"),
    col("Unnamed: 1").alias("shiprocket_price_raw"),
    col("INCREFF").alias("increff_price_raw")
)

# %%
df_clean = df_clean.filter(
    col("service").isNotNull()
)

# %%
df_prices = df_clean \
    .withColumn(
        "shiprocket_price",
        when(
            regexp_extract(col("shiprocket_price_raw"), r"(\d+\.?\d*)", 1) != "",
            regexp_extract(col("shiprocket_price_raw"), r"(\d+\.?\d*)", 1).cast("double")
        ).otherwise(None)
    ) \
    .withColumn(
        "increff_price",
        when(
            regexp_extract(col("increff_price_raw"), r"(\d+\.?\d*)", 1) != "",
            regexp_extract(col("increff_price_raw"), r"(\d+\.?\d*)", 1).cast("double")
        ).otherwise(None)
    )

# %%
df_prices = df_clean \
    .withColumn(
        "shiprocket_price",
        regexp_extract(col("shiprocket_price_raw"), r"(\d+\.?\d*)", 1).cast("double")
    ) \
    .withColumn(
        "increff_price",
        regexp_extract(col("increff_price_raw"), r"(\d+\.?\d*)", 1).cast("double")
    )

# %%
df_prices.show(truncate=False)
# Out:
# +--------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------+----------------+-------------+
# |service                                           |shiprocket_price_raw                                                                                                          |increff_price_raw                                                                                                                              |shiprocket_price|increff_price|
# +--------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------+----------------+-------------+
# |Heads                                             |Price (Per Unit)                                                                                                              |Price (Per Unit)                                                                                                                               |NULL            |NULL         |
# |Inbound (Fresh Stock and RTO)                     |₹4.00                                                                                                                         |4                                                                                                                                              |4.0             |4.0          |
# |Outbound                                          |₹7.00                                                                                                                         |11                                                                                                                                             |7.0             |11.0         |
# |Storage Fee/Cft                                   |₹25.00                                                                                                                        |Rs 0.15/- Per Day                                                                                                                              |25.0            |0.15         |
# |Customer Return with Detailed QC                  |₹6.00                                                                                                                         |15.5                                                                                                                                           |6.0             |15.5         |
# |(A) SCOPE OF WORK and STANDARD OPERATING PROCEDURE|NULL                                                                                                                          |NULL                                                                                                                                           |NULL            |NULL         |
# |Inward                                            |Unloading                                                                                                                     |• Boxes counted and weighed. Data captured in the Maven.                                                                                       |NULL            |NULL         |
# |Outward                                           |Order receipt                                                                                                                 |•  Orders will be received through integration directly into Maven or directly to Maven by the client                                          |NULL            |NULL         |
# |Returns                                           |Inward                                                                                                                        |•  RTO and Customer Returns are received and Inwarded in the warehouse Outer package visible inspection is done before inwarding               |NULL            |NULL         |
# |Inventory management                              |Cycle count                                                                                                                   |•  Daily cycle count to maintain accuracy and deliver SLAs without disrupting regular operations. Complete Inventory to be covered in 3 months.|NULL            |3.0          |
# |(B) MISCELLANEOUS                                 |NULL                                                                                                                          |NULL                                                                                                                                           |NULL            |NULL         |
# |© EXCLUSIONS                                      |NULL                                                                                                                          |NULL                                                                                                                                           |NULL            |NULL         |
# |(D) KEY PERFORMANCE INDICATORS AND COMMERCIALS    |NULL                                                                                                                          |NULL                                                                                                                                           |NULL            |NULL         |
# |Performance Indicators                            |NULL                                                                                                                          |NULL                                                                                                                                           |NULL            |NULL         |
# |Performance Measure                               |Measurement                                                                                                                   |Target                                                                                                                                         |NULL            |NULL         |
# |Monthly Fill Rate                                 |•  Measurement is monthly                                                                                                     |>99.8%                                                                                                                                         |NULL            |99.8         |
# |Daily Processing Capacity                         |•  GRN throughput is subject to a cut-off of 11:00am                                                                          |NULL                                                                                                                                           |11.0            |NULL         |
# |Customer Complaints                               |•  Measurement is monthly                                                                                                     |<0.2%                                                                                                                                          |NULL            |0.2          |
# |Allowed Shrinkage                                 |•  Measured at the time of full audit carried out against Maven inventory by Client or any third party appointed by the Client|<0.2%                                                                                                                                          |NULL            |0.2          |
# |Penalty                                           |•  Penalty for fillrate                                                                                                       |2x of the service fee per affected qty                                                                                                         |NULL            |2.0          |
# +--------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------+----------------+-------------+
# only showing top 20 rows

# %%
df_prices.printSchema()
# Out:
# root
#  |-- service: string (nullable = true)
#  |-- shiprocket_price_raw: string (nullable = true)
#  |-- increff_price_raw: string (nullable = true)
#  |-- shiprocket_price: double (nullable = true)
#  |-- increff_price: double (nullable = true)

# %%
df_prices.filter(
    col("shiprocket_price").isNull() |
    col("increff_price").isNull()
).show()
# Out:
# +--------------------+--------------------+--------------------+----------------+-------------+
# |             service|shiprocket_price_raw|   increff_price_raw|shiprocket_price|increff_price|
# +--------------------+--------------------+--------------------+----------------+-------------+
# |               Heads|    Price (Per Unit)|    Price (Per Unit)|            NULL|         NULL|
# |(A) SCOPE OF WORK...|                NULL|                NULL|            NULL|         NULL|
# |              Inward|           Unloading|• Boxes counted a...|            NULL|         NULL|
# |             Outward|       Order receipt|•  Orders will be...|            NULL|         NULL|
# |             Returns|              Inward|•  RTO and Custom...|            NULL|         NULL|
# |Inventory management|         Cycle count|•  Daily cycle co...|            NULL|          3.0|
# |   (B) MISCELLANEOUS|                NULL|                NULL|            NULL|         NULL|
# |        © EXCLUSIONS|                NULL|                NULL|            NULL|         NULL|
# |(D) KEY PERFORMAN...|                NULL|                NULL|            NULL|         NULL|
# |Performance Indic...|                NULL|                NULL|            NULL|         NULL|
# | Performance Measure|         Measurement|              Target|            NULL|         NULL|
# |   Monthly Fill Rate|•  Measurement is...|              >99.8%|            NULL|         99.8|
# |Daily Processing ...|•  GRN throughput...|                NULL|            11.0|         NULL|
# | Customer Complaints|•  Measurement is...|               <0.2%|            NULL|          0.2|
# |   Allowed Shrinkage|•  Measured at th...|               <0.2%|            NULL|          0.2|
# |             Penalty|•  Penalty for fi...|2x of the service...|            NULL|          2.0|
# |              Others|•  Days of Operat...|     7 days per week|            NULL|          7.0|
# +--------------------+--------------------+--------------------+----------------+-------------+

# %%
df_kpi_base = df_prices.filter(
    col("shiprocket_price").isNotNull() |
    col("increff_price").isNotNull()
)

# %%
df_kpi = df_kpi_base.withColumn(
    "cost_difference",
    col("shiprocket_price") - col("increff_price")
)

# %%
df_kpi = df_kpi.withColumn(
    "cheaper_provider",
    when(col("shiprocket_price") < col("increff_price"), "Shiprocket")
    .when(col("shiprocket_price") > col("increff_price"), "Increff")
    .otherwise("Same / NA")
)

# %%
avg_cost_kpi = df_kpi.selectExpr(
    "avg(shiprocket_price) as avg_shiprocket_cost",
    "avg(increff_price) as avg_increff_cost"
)

# %%
avg_cost_kpi.show()
# Out:
# +-------------------+------------------+
# |avg_shiprocket_cost|  avg_increff_cost|
# +-------------------+------------------+
# |               10.6|14.284999999999997|
# +-------------------+------------------+

# %%
overall_kpi = df_kpi.selectExpr(
    "sum(shiprocket_price) as total_shiprocket_cost",
    "sum(increff_price) as total_increff_cost",
    """
    (sum(shiprocket_price) - sum(increff_price))
    / sum(shiprocket_price) * 100
    as cost_saving_percentage
    """
)
overall_kpi.show()
# Out:
# +---------------------+------------------+----------------------+
# |total_shiprocket_cost|total_increff_cost|cost_saving_percentage|
# +---------------------+------------------+----------------------+
# |                 53.0|142.84999999999997|    -169.5283018867924|
# +---------------------+------------------+----------------------+

# %%
df_kpi_final = df_kpi.select(
    "service",
    "shiprocket_price",
    "increff_price",
    "cost_difference",
    "cheaper_provider"
)
df_kpi_final.show(truncate=False)
# Out:
# +--------------------------------+----------------+-------------+---------------+----------------+
# |service                         |shiprocket_price|increff_price|cost_difference|cheaper_provider|
# +--------------------------------+----------------+-------------+---------------+----------------+
# |Inbound (Fresh Stock and RTO)   |4.0             |4.0          |0.0            |Same / NA       |
# |Outbound                        |7.0             |11.0         |-4.0           |Shiprocket      |
# |Storage Fee/Cft                 |25.0            |0.15         |24.85          |Increff         |
# |Customer Return with Detailed QC|6.0             |15.5         |-9.5           |Shiprocket      |
# |Inventory management            |NULL            |3.0          |NULL           |Same / NA       |
# |Monthly Fill Rate               |NULL            |99.8         |NULL           |Same / NA       |
# |Daily Processing Capacity       |11.0            |NULL         |NULL           |Same / NA       |
# |Customer Complaints             |NULL            |0.2          |NULL           |Same / NA       |
# |Allowed Shrinkage               |NULL            |0.2          |NULL           |Same / NA       |
# |Penalty                         |NULL            |2.0          |NULL           |Same / NA       |
# |Others                          |NULL            |7.0          |NULL           |Same / NA       |
# +--------------------------------+----------------+-------------+---------------+----------------+

# %%
df_kpi_final.write \
    .mode("overwrite") \
    .parquet("/content/output/warehouse_cost_kpis")

# %%
spark.read.parquet("/content/output/warehouse_cost_kpis").show(truncate=False)
# Out:
# +--------------------------------+----------------+-------------+---------------+----------------+
# |service                         |shiprocket_price|increff_price|cost_difference|cheaper_provider|
# +--------------------------------+----------------+-------------+---------------+----------------+
# |Inbound (Fresh Stock and RTO)   |4.0             |4.0          |0.0            |Same / NA       |
# |Outbound                        |7.0             |11.0         |-4.0           |Shiprocket      |
# |Storage Fee/Cft                 |25.0            |0.15         |24.85          |Increff         |
# |Customer Return with Detailed QC|6.0             |15.5         |-9.5           |Shiprocket      |
# |Inventory management            |NULL            |3.0          |NULL           |Same / NA       |
# |Monthly Fill Rate               |NULL            |99.8         |NULL           |Same / NA       |
# |Daily Processing Capacity       |11.0            |NULL         |NULL           |Same / NA       |
# |Customer Complaints             |NULL            |0.2          |NULL           |Same / NA       |
# |Allowed Shrinkage               |NULL            |0.2          |NULL           |Same / NA       |
# |Penalty                         |NULL            |2.0          |NULL           |Same / NA       |
# |Others                          |NULL            |7.0          |NULL           |Same / NA       |
# +--------------------------------+----------------+-------------+---------------+----------------+

# %%
df_kpi_final.explain(True)
# Out:
# == Parsed Logical Plan ==
# 'Project ['service, 'shiprocket_price, 'increff_price, 'cost_difference, 'cheaper_provider]
# +- Project [service#39, shiprocket_price_raw#40, increff_price_raw#41, shiprocket_price#101, increff_price#102, cost_difference#141, CASE WHEN (shiprocket_price#101 < increff_price#102) THEN Shiprocket WHEN (shiprocket_price#101 > increff_price#102) THEN Increff ELSE Same / NA END AS cheaper_provider#250]
#    +- Project [service#39, shiprocket_price_raw#40, increff_price_raw#41, shiprocket_price#101, increff_price#102, cost_difference#141, CASE WHEN (shiprocket_price#101 < increff_price#102) THEN Shiprocket WHEN (shiprocket_price#101 > increff_price#102) THEN Increff ELSE Same / NA END AS cheaper_provider#142]
#       +- Project [service#39, shiprocket_price_raw#40, increff_price_raw#41, shiprocket_price#101, increff_price#102, (shiprocket_price#101 - increff_price#102) AS cost_difference#141]
#          +- Filter (isnotnull(shiprocket_price#101) OR isnotnull(increff_price#102))
#             +- Project [service#39, shiprocket_price_raw#40, increff_price_raw#41, shiprocket_price#101, CASE WHEN NOT (regexp_extract(increff_price_raw#41, (\d+\.?\d*), 1) = ) THEN cast(regexp_extract(increff_price_raw#41, (\d+\.?\d*), 1) as double) ELSE cast(null as double) END AS increff_price#102]
#                +- Project [service#39, shiprocket_price_raw#40, increff_price_raw#41, CASE WHEN NOT (regexp_extract(shiprocket_price_raw#40, (\d+\.?\d*), 1) = ) THEN cast(regexp_extract(shiprocket_price_raw#40, (\d+\.?\d*), 1) as double) ELSE cast(null as double) END AS shiprocket_price#101]
#                   +- Filter isnotnull(service#39)
#                      +- Project [Shiprocket#18 AS service#39, Unnamed: 1#19 AS shiprocket_price_raw#40, INCREFF#20 AS increff_price_raw#41]
#                         +- Relation [index#17,Shiprocket#18,Unnamed: 1#19,INCREFF#20] csv
#
# == Analyzed Logical Plan ==
# service: string, shiprocket_price: double, increff_price: double, cost_difference: double, cheaper_provider: string
# Project [service#39, shiprocket_price#101, increff_price#102, cost_difference#141, cheaper_provider#250]
# +- Project [service#39, shiprocket_price_raw#40, increff_price_raw#41, shiprocket_price#101, increff_price#102, cost_difference#141, CASE WHEN (shiprocket_price#101 < increff_price#102) THEN Shiprocket WHEN (shiprocket_price#101 > increff_price#102) THEN Increff ELSE Same / NA END AS cheaper_provider#250]
#    +- Project [service#39, shiprocket_price_raw#40, increff_price_raw#41, shiprocket_price#101, increff_price#102, cost_difference#141, CASE WHEN (shiprocket_price#101 < increff_price#102) THEN Shiprocket WHEN (shiprocket_price#101 > increff_price#102) THEN Increff ELSE Same / NA END AS cheaper_provider#142]
#       +- Project [service#39, shiprocket_price_raw#40, increff_price_raw#41, shiprocket_price#101, increff_price#102, (shiprocket_price#101 - increff_price#102) AS cost_difference#141]
#          +- Filter (isnotnull(shiprocket_price#101) OR isnotnull(increff_price#102))
#             +- Project [service#39, shiprocket_price_raw#40, increff_price_raw#41, shiprocket_price#101, CASE WHEN NOT (regexp_extract(increff_price_raw#41, (\d+\.?\d*), 1) = ) THEN cast(regexp_extract(increff_price_raw#41, (\d+\.?\d*), 1) as double) ELSE cast(null as double) END AS increff_price#102]
#                +- Project [service#39, shiprocket_price_raw#40, increff_price_raw#41, CASE WHEN NOT (regexp_extract(shiprocket_price_raw#40, (\d+\.?\d*), 1) = ) THEN cast(regexp_extract(shiprocket_price_raw#40, (\d+\.?\d*), 1) as double) ELSE cast(null as double) END AS shiprocket_price#101]
#                   +- Filter isnotnull(service#39)
#                      +- Project [Shiprocket#18 AS service#39, Unnamed: 1#19 AS shiprocket_price_raw#40, INCREFF#20 AS increff_price_raw#41]
#                         +- Relation [index#17,Shiprocket#18,Unnamed: 1#19,INCREFF#20] csv
#
# == Optimized Logical Plan ==
# Project [service#39, shiprocket_price#101, increff_price#102, (shiprocket_price#101 - increff_price#102) AS cost_difference#141, CASE WHEN (shiprocket_price#101 < increff_price#102) THEN Shiprocket WHEN (shiprocket_price#101 > increff_price#102) THEN Increff ELSE Same / NA END AS cheaper_provider#250]
# +- Project [Shiprocket#18 AS service#39, CASE WHEN NOT (regexp_extract(Unnamed: 1#19, (\d+\.?\d*), 1) = ) THEN cast(regexp_extract(Unnamed: 1#19, (\d+\.?\d*), 1) as double) END AS shiprocket_price#101, CASE WHEN NOT (regexp_extract(INCREFF#20, (\d+\.?\d*), 1) = ) THEN cast(regexp_extract(INCREFF#20, (\d+\.?\d*), 1) as double) END AS increff_price#102]
#    +- Filter (isnotnull(Shiprocket#18) AND (CASE WHEN NOT (regexp_extract(Unnamed: 1#19, (\d+\.?\d*), 1) = ) THEN isnotnull(cast(regexp_extract(Unnamed: 1#19, (\d+\.?\d*), 1) as double)) ELSE false END OR CASE WHEN NOT (regexp_extract(INCREFF#20, (\d+\.?\d*), 1) = ) THEN isnotnull(cast(regexp_extract(INCREFF#20, (\d+\.?\d*), 1) as double)) ELSE false END))
#       +- Relation [index#17,Shiprocket#18,Unnamed: 1#19,INCREFF#20] csv
#
# == Physical Plan ==
# *(1) Project [service#39, shiprocket_price#101, increff_price#102, (shiprocket_price#101 - increff_price#102) AS cost_difference#141, CASE WHEN (shiprocket_price#101 < increff_price#102) THEN Shiprocket WHEN (shiprocket_price#101 > increff_price#102) THEN Increff ELSE Same / NA END AS cheaper_provider#250]
# +- *(1) Project [Shiprocket#18 AS service#39, CASE WHEN NOT (regexp_extract(Unnamed: 1#19, (\d+\.?\d*), 1) = ) THEN cast(regexp_extract(Unnamed: 1#19, (\d+\.?\d*), 1) as double) END AS shiprocket_price#101, CASE WHEN NOT (regexp_extract(INCREFF#20, (\d+\.?\d*), 1) = ) THEN cast(regexp_extract(INCREFF#20, (\d+\.?\d*), 1) as double) END AS increff_price#102]
#    +- *(1) Filter (isnotnull(Shiprocket#18) AND (CASE WHEN NOT (regexp_extract(Unnamed: 1#19, (\d+\.?\d*), 1) = ) THEN isnotnull(cast(regexp_extract(Unnamed: 1#19, (\d+\.?\d*), 1) as double)) ELSE false END OR CASE WHEN NOT (regexp_extract(INCREFF#20, (\d+\.?\d*), 1) = ) THEN isnotnull(cast(regexp_extract(INCREFF#20, (\d+\.?\d*), 1) as double)) ELSE false END))
#       +- FileScan csv [Shiprocket#18,Unnamed: 1#19,INCREFF#20] Batched: false, DataFilters: [isnotnull(Shiprocket#18), (CASE WHEN NOT (regexp_extract(Unnamed: 1#19, (\d+\.?\d*), 1) = ) THEN..., Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/content/Cloud Warehouse Compersion Chart.csv], PartitionFilters: [], PushedFilters: [IsNotNull(Shiprocket)], ReadSchema: struct<Shiprocket:string,Unnamed: 1:string,INCREFF:string>
