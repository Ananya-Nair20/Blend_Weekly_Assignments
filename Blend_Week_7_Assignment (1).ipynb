# %%
import pandas as pd
# !pip install pymongo
from pymongo import MongoClient
from datetime import datetime

# %% [markdown]
# ## Note on MongoDB Connection
#
# The dataset was imported into MongoDB Atlas using MongoDB Compass.
# While PyMongo code for CRUD operations is included, executing write
# operations from the hosted notebook environment resulted in SSL
# handshake issues due to network restrictions. Therefore, CRUD logic
# is demonstrated programmatically without modifying the main dataset.

# %%
# Dummy CRUD demo document
test_doc = {
    "order": {
        "id": "CRUD_TEST_001",
        "date": datetime(2022, 4, 15),
        "status": "Test Order"
    },
    "product": {
        "amount": 999
    },
    "shipping": {
        "state": "TEST_STATE"
    }
}

# %%
# collection.insert_one(test_doc)
print("CREATE: Dummy document insertion logic written")
# Out:
# CREATE: Dummy document insertion logic written

# %%
# collection.find_one({"order.id": "CRUD_TEST_001"})
print("READ: Dummy document fetch logic written")
# Out:
# READ: Dummy document fetch logic written

# %%
# collection.update_one(
#     {"order.id": "CRUD_TEST_001"},
#     {"$set": {"product.amount": 1499}}
# )
print("UPDATE: Dummy document update logic written")
# Out:
# UPDATE: Dummy document update logic written
